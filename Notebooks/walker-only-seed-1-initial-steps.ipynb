# %%
import os
import shutil

# Setup: Check for repo and enforce working directory
repo_path = "/kaggle/working/rl_sf"
if not os.path.exists(repo_path):
    print("--> Repository missing. Cloning now...")
    # !git clone -b optimization https://github.com/flaviogeuforbio/rl-with-sf-for-mujoco {repo_path}

# Change directory explicitly to where the script lives
# %cd {repo_path}
# Out:
# --> Repository missing. Cloning now...
# Cloning into '/kaggle/working/rl_sf'...
# remote: Enumerating objects: 3916, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 3916 (delta 2), reused 6 (delta 2), pack-reused 3910 (from 3)
# Receiving objects: 100% (3916/3916), 828.00 MiB | 33.95 MiB/s, done.
# Resolving deltas: 100% (765/765), done.
# Updating files: 100% (2430/2430), done.
# /kaggle/working/rl_sf

# %%
import torch
print("torch:", torch.version)
print("cuda available:", torch.cuda.is_available())
print("device:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU")
# Out:
# torch: <module 'torch.version' from '/usr/local/lib/python3.12/dist-packages/torch/version.py'>
# cuda available: False
# device: CPU

# %%
# %ls
# Out:
# ActorCritic.py                        render_agent.py
# args_plot_average_results_walker.txt  render_args_cheetah.txt
# args_render_agent.txt                 render_args_walker_transfer.txt
# artifacts/                            requirements.txt
# diagnose_feature_scales.py            run_behavioral_diagnostics_mod.py
# diagnose_psi.py                       run_behavioral_diagnostics.py
# diagnose_rollout_dynamics.py          run_psi_diagnostic_mod.py
# OLD_2_train_cheetah_walker.py         run_psi_diagnostic.py
# OLD_train_cheetah_walker.py           train_cheetah_walker.py
# plot_average_results.py               train_sf_ddpg.py
# PlotResults.py                        transfer_vs_scratch_comparison.pdf
# plot_rollout_timeseries.py            transfer_vs_scratch_comparison.png
# __pycache__/                          utils.py
# QuickPlot.py                          zero_shot_eval.py
# quick_test.py

# %%
# !python -m pip install mujoco
# Out:
# Collecting mujoco
#   Downloading mujoco-3.10.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.7/232.7 kB 4.1 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from mujoco) (1.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.12/dist-packages (from mujoco) (1.14.0)
# Collecting glfw (from mujoco)
#   Downloading glfw-2.10.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.py39.py310.py311.py312.py313.py314-none-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mujoco) (2.4.6)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.12/dist-packages (from mujoco) (3.1.10)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco) (2025.3.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco) (4.15.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.12/dist-packages (from etils[epath]->mujoco) (3.23.0)
# Downloading mujoco-3.10.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (20.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 61.1 MB/s eta 0:00:00:00:0100:01
# Downloading glfw-2.10.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.py39.py310.py311.py312.py313.py314-none-manylinux_2_28_x86_64.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.5/243.5 kB 10.2 MB/s eta 0:00:00
# Installing collected packages: glfw, mujoco
# Successfully installed glfw-2.10.0 mujoco-3.10.0

# %%
import os
import shutil

# --- PHASE 1: INITIAL RUN ---
seed = 1
folder_name = f"seed_{seed}_scratch" # Dynamic folder name

# For a quick sanity check
# STEPS_PER_PHASE = "4000"  # target
# RUN_STEPS_LIMIT = "8000"   # chunk limit
# SAVE_FREQ = "1000"         # Synchronized with limit

STEPS_PER_PHASE = "4000000"  # 4M target
RUN_STEPS_LIMIT = "1000000"   # chunk limit
SAVE_FREQ = "100000"         # Synchronized with limit
GAMMA_VAL = "0.99"
LAMBDA_Q = "1.0" 
LAMBDA_VEC = "1.0" 
#RESUME_DIR = "/kaggle/input/datasets/adrianoarceri/checkpoint" # change the last name accoording to how you name the dataset, and the previous folder is your username
# Here I don't need the resume_dir!!

RUN_NAME_SEQ = f"Walker_from_scratch_gamma_{GAMMA_VAL.replace('.', '_')}_lq_{LAMBDA_Q.replace('.', '_')}_lvec_{LAMBDA_VEC.replace('.', '_')}_stepsxphase_{STEPS_PER_PHASE}"

# Create the dynamic directory
kaggle_output_folder = f"/kaggle/working/{folder_name}"
os.makedirs(kaggle_output_folder, exist_ok=True)

local_path_seq = f"/kaggle/working/rl_sf/artifacts/walker/{RUN_NAME_SEQ}"


print(f"\n--- EXECUTING SEED {seed} ---")

print("-> Running Walker Training from scratch...")
# !python -u train_cheetah_walker.py --steps_per_phase {STEPS_PER_PHASE} --save_freq {SAVE_FREQ} --baseline --run_name {RUN_NAME_SEQ} --gamma {GAMMA_VAL} --lambda_q {LAMBDA_Q} --lambda_vec {LAMBDA_VEC} --seed {seed} --run_steps_limit {RUN_STEPS_LIMIT} --walker_only

if os.path.exists(local_path_seq):
    final_dest_seq = os.path.join(kaggle_output_folder, RUN_NAME_SEQ)
    shutil.copytree(local_path_seq, final_dest_seq, dirs_exist_ok=True)
    print(f"--> Scratch Learning (walker only) data saved in: {final_dest_seq}")

print("\n--> Zipping results for download...")
# %cd /kaggle/working/
# !zip -r {folder_name}.zip {folder_name}/
# %cd /kaggle/working/rl_sf
# Out:
# --- EXECUTING SEED 1 ---
# -> Running Walker Training from scratch...
# ==================================================
# Training SF-DDPG...
# ==================================================
# --- Starting Phase 1 (Walker) ---
# Step: 196 | Episodes: 10 | Avg Return: 18.72 | C Loss: 0.0000 | Q Loss: 0.0000 | Vec Loss: 0.0000
# Step: 383 | Episodes: 20 | Avg Return: 17.68 | C Loss: 0.0000 | Q Loss: 0.0000 | Vec Loss: 0.0000
# Step: 554 | Episodes: 30 | Avg Return: 16.23 | C Loss: 0.0000 | Q Loss: 0.0000 | Vec Loss: 0.0000
# Step: 737 | Episodes: 40 | Avg Return: 17.30 | C Loss: 0.0000 | Q Loss: 0.0000 | Vec Loss: 0.0000
# Step: 950 | Episodes: 50 | Avg Return: 20.45 | C Loss: 0.0000 | Q Loss: 0.0000 | Vec Loss: 0.0000
# --> [SAVE] Checkpoint saved at Phase 1, Step 1000
# Step: 1053 | Episodes: 60 | Avg Return: 9.32 | C Loss: 0.0750 | Q Loss: 0.0366 | Vec Loss: 0.0384
# Step: 1113 | Episodes: 70 | Avg Return: 4.97 | C Loss: 0.1528 | Q Loss: 0.0856 | Vec Loss: 0.0672
# Step: 1173 | Episodes: 80 | Avg Return: 4.97 | C Loss: 0.0823 | Q Loss: 0.0365 | Vec Loss: 0.0458
# Step: 1233 | Episodes: 90 | Avg Return: 4.97 | C Loss: 0.1092 | Q Loss: 0.0600 | Vec Loss: 0.0492
# Step: 1293 | Episodes: 100 | Avg Return: 4.97 | C Loss: 0.1770 | Q Loss: 0.0829 | Vec Loss: 0.0941
# Step: 1353 | Episodes: 110 | Avg Return: 4.97 | C Loss: 0.1309 | Q Loss: 0.0659 | Vec Loss: 0.0650
# Step: 3933 | Episodes: 540 | Avg Return: 4.97 | C Loss: 0.0341 | Q Loss: 0.0186 | Vec Loss: 0.0155
# Step: 3993 | Episodes: 550 | Avg Return: 4.97 | C Loss: 0.0552 | Q Loss: 0.0194 | Vec Loss: 0.0358
# ==================================================
# Training DDPG...
# ==================================================
# --- Starting Task 2 (Walker Forward) from Scratch ---
# Step: 196 | Episodes: 10 | Avg Return: 18.72 | C Loss: 0.0000
# Step: 383 | Episodes: 20 | Avg Return: 17.68 | C Loss: 0.0000
# Step: 554 | Episodes: 30 | Avg Return: 16.23 | C Loss: 0.0000
# Step: 737 | Episodes: 40 | Avg Return: 17.30 | C Loss: 0.0000
# Step: 950 | Episodes: 50 | Avg Return: 20.45 | C Loss: 0.0000
# --> [SAVE] Checkpoint saved at Phase 1, Step 1000
# Step: 1111 | Episodes: 60 | Avg Return: 15.33 | C Loss: 0.0847
# Step: 1230 | Episodes: 70 | Avg Return: 10.83 | C Loss: 0.0947
# Step: 1350 | Episodes: 80 | Avg Return: 10.93 | C Loss: 0.0515
# Step: 1470 | Episodes: 90 | Avg Return: 10.93 | C Loss: 0.0878
# Step: 1587 | Episodes: 100 | Avg Return: 10.63 | C Loss: 0.1033
# Step: 1703 | Episodes: 110 | Avg Return: 10.54 | C Loss: 0.0531
# Step: 1821 | Episodes: 120 | Avg Return: 10.73 | C Loss: 0.0665
# Step: 1938 | Episodes: 130 | Avg Return: 10.63 | C Loss: 0.0624
# --> [SAVE] Checkpoint saved at Phase 1, Step 2000
# Step: 2057 | Episodes: 140 | Avg Return: 10.83 | C Loss: 0.1052
# Step: 2176 | Episodes: 150 | Avg Return: 10.83 | C Loss: 0.0415
# Step: 2294 | Episodes: 160 | Avg Return: 10.73 | C Loss: 0.0797
# Step: 2438 | Episodes: 170 | Avg Return: 13.49 | C Loss: 0.2772
# Step: 2565 | Episodes: 180 | Avg Return: 11.63 | C Loss: 0.2260
# Step: 2686 | Episodes: 190 | Avg Return: 11.03 | C Loss: 0.2692
# Step: 2900 | Episodes: 200 | Avg Return: 20.60 | C Loss: 0.1559
# --> [SAVE] Checkpoint saved at Phase 1, Step 3000
# Step: 3973 | Episodes: 210 | Avg Return: 108.47 | C Loss: 0.2881
# --> Scratch Learning (walker only) data saved in: /kaggle/working/seed_1_scratch/Walker_from_scratch_gamma_0_99_lq_1_0_lvec_1_0_stepsxphase_4000
#
# --> Zipping results for download...
# /kaggle/working
#   adding: seed_1_scratch/ (stored 0%)
#   adding: seed_1_scratch/Walker_from_scratch_gamma_0_99_lq_1_0_lvec_1_0_stepsxphase_4000/ (stored 0%)
#   adding: seed_1_scratch/Walker_from_scratch_gamma_0_99_lq_1_0_lvec_1_0_stepsxphase_4000/seed_1/ (stored 0%)
#   adding: seed_1_scratch/Walker_from_scratch_gamma_0_99_lq_1_0_lvec_1_0_stepsxphase_4000/seed_1/sf_actor_1.pth (deflated 8%)
#   adding: seed_1_scratch/Walker_from_scratch_gamma_0_99_lq_1_0_lvec_1_0_stepsxphase_4000/seed_1/sf_ddpg_returns.json (deflated 59%)
#   adding: seed_1_scratch/Walker_from_scratch_gamma_0_99_lq_1_0_lvec_1_0_stepsxphase_4000/seed_1/q_critic_1.pth (deflated 8%)
#   adding: seed_1_scratch/Walker_from_scratch_gamma_0_99_lq_1_0_lvec_1_0_stepsxphase_4000/seed_1/q_actor_1.pth (deflated 8%)
#   adding: seed_1_scratch/Walker_from_scratch_gamma_0_99_lq_1_0_lvec_1_0_stepsxphase_4000/seed_1/sf_critic_1.pth (deflated 8%)
#   adding: seed_1_scratch/Walker_from_scratch_gamma_0_99_lq_1_0_lvec_1_0_stepsxphase_4000/seed_1/ddpg_returns.json (deflated 56%)
#   adding: seed_1_scratch/Walker_from_scratch_gamma_0_99_lq_1_0_lvec_1_0_stepsxphase_4000/seed_1/checkpoint_sf.pt (deflated 32%)
#   adding: seed_1_scratch/Walker_from_scratch_gamma_0_99_lq_1_0_lvec_1_0_stepsxphase_4000/seed_1/checkpoint_q.pt (deflated 35%)
# /kaggle/working/rl_sf
